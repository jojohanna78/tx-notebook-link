# %% [markdown]
# # Exemple Jupytercards

# %%
# %pip install jupytercards

# %%
from jupytercards import display_flashcards

cards = [
    {
        "front": "Que signifie l'étape create dans notebook.link ?",
        "back": "La création et la gestion d'un environnement de développement spécifique."
    },
    {
        "front": "Que signifie l'étape build dans notebook.link ?",
        "back": "La génération de contenus (pages web, applications, slideshows)."
    },
    {
        "front": "Que signifie l'étape share dans notebook.link ?",
        "back": "Le déploiement et le partage via un dépôt GitHub."
    }
]

display_flashcards(cards)
